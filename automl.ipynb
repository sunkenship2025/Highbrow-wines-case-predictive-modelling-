# %%
import pycaret as pc
import pandas as pd

# %%
df=pd.read_csv('/Users/pranavreddy/Desktop/projects/wines/Highbrow-wines-case-predictive-modelling-/data_2016.csv')

# %%
# Check and drop missing values in the target column
print('Missing before:', df['bought_highbrow_wines'].isna().sum())
df = df.dropna(subset=['bought_highbrow_wines']).reset_index(drop=True)
print('Missing after:', df['bought_highbrow_wines'].isna().sum())
# Out:
# Missing before: 4
# Missing after: 0

# %%
from pycaret.classification import *
s=setup(df,target='bought_highbrow_wines')
# Out:
# <style type="text/css">
# #T_c2d3c_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c2d3c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2d3c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c2d3c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2d3c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c2d3c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c2d3c_row0_col1" class="data row0 col1" >5512</td>
#     </tr>
#     <tr>
#       <th id="T_c2d3c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c2d3c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c2d3c_row1_col1" class="data row1 col1" >bought_highbrow_wines</td>
#     </tr>
#     <tr>
#       <th id="T_c2d3c_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best=compare_models()
# Out:
# <style type="text/css">
# #T_78ee5 th {
#   text-align: left;
# }
# ...
